# %% [markdown]
# from https://nbviewer.org/gist/yoavg/d76121dfde2618422139

# %%
from collections import *

def train_char_lm(fname, order=4):
    data = open(fname, 'r', errors='ignore').read()
    lm = defaultdict(Counter)
    pad = "~" * order
    data = pad + data
    for i in range(len(data)-order):
        history, char = data[i:i+order], data[i+order]
        lm[history][char]+=1
    def normalize(counter):
        s = float(sum(counter.values()))
        return [(c,cnt/s) for c,cnt in counter.items()]
    outlm = {hist:normalize(chars) for hist, chars in lm.items()}
    return outlm

# %%
# !wget https://cs.stanford.edu/people/karpathy/char-rnn/shakespeare_input.txt
# Out:
# --2025-09-09 09:59:20--  https://cs.stanford.edu/people/karpathy/char-rnn/shakespeare_input.txt
# Resolving cs.stanford.edu (cs.stanford.edu)... 171.64.64.64
# Connecting to cs.stanford.edu (cs.stanford.edu)|171.64.64.64|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4573338 (4.4M) [text/plain]
# Saving to: ‘shakespeare_input.txt.1’
#
# shakespeare_input.t 100%[===================>]   4.36M  15.0MB/s    in 0.3s
#
# 2025-09-09 09:59:20 (15.0 MB/s) - ‘shakespeare_input.txt.1’ saved [4573338/4573338]

# %%
lm = train_char_lm("shakespeare_input.txt", order=4)

# %%
lm['ello']
# Out:
# [('r', 0.059625212947189095),
#  ('w', 0.817717206132879),
#  ('u', 0.03747870528109029),
#  (',', 0.027257240204429302),
#  (' ', 0.013628620102214651),
#  ('.', 0.0068143100511073255),
#  ('?', 0.0068143100511073255),
#  (':', 0.005110732538330494),
#  ('n', 0.0017035775127768314),
#  ("'", 0.017035775127768313),
#  ('!', 0.0068143100511073255)]

# %%
lm['Firs']
# Out:
# [('t', 1.0)]

# %%
lm['rst ']
# Out:
# [('C', 0.09550561797752809),
#  ('f', 0.011235955056179775),
#  ('i', 0.016853932584269662),
#  ('t', 0.05377207062600321),
#  ('u', 0.0016051364365971107),
#  ('S', 0.16292134831460675),
#  ('h', 0.019261637239165328),
#  ('s', 0.03290529695024077),
#  ('R', 0.0008025682182985554),
#  ('b', 0.024879614767255216),
#  ('c', 0.012841091492776886),
#  ('O', 0.018459069020866775),
#  ('w', 0.024077046548956663),
#  ('a', 0.02247191011235955),
#  ('m', 0.02247191011235955),
#  ('n', 0.020064205457463884),
#  ('I', 0.009630818619582664),
#  ('L', 0.10674157303370786),
#  ('M', 0.0593900481540931),
#  ('l', 0.01043338683788122),
#  ('o', 0.030497592295345103),
#  ('H', 0.0040128410914927765),
#  ('d', 0.015248796147672551),
#  ('W', 0.033707865168539325),
#  ('K', 0.008025682182985553),
#  ('q', 0.0016051364365971107),
#  ('G', 0.0898876404494382),
#  ('g', 0.011235955056179775),
#  ('k', 0.0040128410914927765),
#  ('e', 0.0032102728731942215),
#  ('y', 0.002407704654895666),
#  ('r', 0.0072231139646869984),
#  ('p', 0.00882825040128411),
#  ('A', 0.0056179775280898875),
#  ('P', 0.014446227929373997),
#  ('F', 0.012038523274478331),
#  ('v', 0.002407704654895666),
#  ('T', 0.0032102728731942215),
#  ('D', 0.0032102728731942215),
#  ('B', 0.009630818619582664),
#  ('N', 0.0008025682182985554),
#  ("'", 0.0008025682182985554),
#  ('E', 0.0016051364365971107)]

# %%
from random import random

def generate_letter(lm, history, order):
        history = history[-order:]
        dist = lm[history]
        x = random()
        for c,v in dist:
            x = x - v
            if x <= 0: return c

# %%
def generate_text(lm, order, nletters=1000):
    history = "~" * order
    out = []
    for i in range(nletters):
        c = generate_letter(lm, history, order)
        history = history[-order:] + c
        out.append(c)
    return "".join(out)

# %%
lm = train_char_lm("shakespeare_input.txt", order=2)
print(generate_text(lm, 2))
# Out:
# Firt wen, hat lorne at be wo hat make thated no blempop lifeck sublovered: and,
# A pot well go, I whan hidee slaven.
#
# Deme, wor eas day fores ther abe me to my with,
# LOVELLOUCIO:
# I prop est
# Thatio.
#
# His bearcheink the ind fors forn muz!
# To say 'gain to th love thims! frian's dern Rome.
#
# A shatis lier,
# Theeptice bes.
# Of my.
#
# MISTING HENTIMONUS:
#
# Gode kepose he and misell hers, in am thee, therce, thy fords themort thy you not the you the kne;
# I all astoonciagessure'll to youre?
#
# Sir.
#
# CALSTER:
# And am youble'll
# hall them;
# We to be wis a light goo be com will wholer dientell not shooke, at 'tweels.
#
# KING Juld shoubjece.
#
# But und un he to th
# The reved 't.
#
# Orld plat Good supplat if hims you dess.
# Win kinevedy, my is
# AUFF:
# Shaven him.
#
# For?
#
# By foever morch tray is theress nou drin, will usille.
#
# Somed Sird,
# As swome eve sh'd by ch greetian he done, bast ware now's with thim mid ner th glay, arts lennot we is whan a lis witill
# bet the practier mordefor to therem ou dog strus mor tice my is w

# %%
lm = train_char_lm("shakespeare_input.txt", order=4)
print(generate_text(lm, 4))
# Out:
# First, we cardinane,
# And ruled: I music, have your late. Mum, thy the king nature
# Then I wot offend they was shepherd foils of France!
#
# FLUELLE:
# Is goose done own some o'ertake to the had
# And him:
# Good with visions, poor keep the you should, forgive the be you helps heaving greated. What, from here had as egg is seen
# Order no
# mortable, discomforth but now thinks I can now now my father leisure; for join
# In equire your mouther's affice of my tract agains of the same eyes of man old, and
# That their jade my diable: yet him.
#
# FALSTAFF:
# Art that dead this ecus gold? a queen
# As England?
# Well, being stand am I point to morrow.
#
# CASCA:
# Thou not: thee up
# Unto more I can rever patterfect of many is is slivers only seal of thou coach the desire monastincture-like this trange is,
# like presentlemen, Jug! I had them, well; young Octavia beauty,
# And succession! Tranion be drinkle fined from he city horses and see
# swagger than I not
# To lead,
# Because highness of fight it raggars.
#
# GLOUCESTER:
# He's my g

# %%
lm = train_char_lm("shakespeare_input.txt", order=7)
print(generate_text(lm, 7))
# Out:
# First Citizen:
# Ay, sir, not I;
# It is a history:
# Night have shut upon his oath,
# Mark'd he frankness of your brows,
# As infinitely brethren slain?
#
# ORLANDO:
# Who drown me,
# Where my thumb at your gloves in his happy words, considerate, be merry Shrove-tide.
# Be merry wander'd at it: I bought but hear you sir? Can you this which speed fairness, and matter father'd and stomachers,
# Upon whose bought to-day,
# 'This gentlemen born blows and all
# The usurpers swarm of mine,
# That he hath private. Your hands, hell's torments me to my charge you, sir? why, then I'll send destroy'd the green you smell of love, that hour or five hundred knight; and thy audacity?
#
# POMPEY:
# What, ho!
# They have used as the madam, so you darest fate aside, I judge and
# board and frailty,
# and that we, that ne'er dream'd; thy master's badge, old bonds. O Imogen.
#
# First Soldiers for this, I will not be
# so: ever was:
# In memory,
# And let him before, lest to this? Consider,
# When thou outrun,
# By violent hands
# Should be loathness to be

# %%
lm = train_char_lm("shakespeare_input.txt", order=10)
print(generate_text(lm, 10))
# Out:
# First Citizen:
# You must away;
# For your fair princess,
# Thou diedst, a most pernicious faction: therefore let's have one bout with his statutes of this month I have darted at the high and low. Our foe was princely hypocrite, takes offence at the governess of it.
#
# BARDOLPH:
# Good morning taste,
# To give the first truth that e'er I saw, the first complain,
# And she, too desperate of obtaining of my love,
# That I am willing to keep in; therefore hurt not: but
# your people,
# Our purpose. Doth your house: give
# notice to such persons.
#
# KING HENRY VIII:
# I then moved you hither, sirrah. Can you love me, let's away.
#
# First Murderer:
# My lord, here comes more cause that I, poor Margaret my name, great clerks have purposed!
# Coming to look on that altogether directed by the king for this thy fair way!
#
# OCTAVIA:
# My noble uncle, Lancaster
# Doth speak so true at first wounded thee:
# A thousand souls and twenty times the captive Grecian Diomed, a whole week by days,
# Did haunt you in this man,
# To ease ourselves,

# %%
# !wget http://cs.stanford.edu/people/karpathy/char-rnn/linux_input.txt
# Out:
# URL transformed to HTTPS due to an HSTS policy
# --2025-09-09 10:01:00--  https://cs.stanford.edu/people/karpathy/char-rnn/linux_input.txt
# Resolving cs.stanford.edu (cs.stanford.edu)... 171.64.64.64
# Connecting to cs.stanford.edu (cs.stanford.edu)|171.64.64.64|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6206996 (5.9M) [text/plain]
# Saving to: ‘linux_input.txt’
#
# linux_input.txt     100%[===================>]   5.92M  33.2MB/s    in 0.2s
#
# 2025-09-09 10:01:01 (33.2 MB/s) - ‘linux_input.txt’ saved [6206996/6206996]

# %%
lm = train_char_lm("linux_input.txt", order=10)
print(generate_text(lm, 10))
# Out:
# ~~~~~~~~~~~~/*
#  * linux/kernel.h>
# #include <trace/events/syscalls.h>
# #include <linux/acct.h>
# #include <asm/processor.
# 			 */
# 			raw_spin_unlock_irqrestore(&grp->lock);
# }
#
# /**
#  *	handler or from a
#  * hardware irq chips like
# 	 * MSI based interrupt context. The
# 	 * future iteration
# 		 * handlers (with rcu_read_lock_sched();
# }
#
# /**
#  * acct_process(struct lock_class *class)
# {
# 	return -1;
#
# 	gran = wakeup_tracer_init,
# 	.free			= event_trigger_ops, trigger_data *test,
# 			   struct klp_ops *ops;
#
# 	ops->flags & WQ_FREEZABLE, 0);
#
# 	return 0;
# }
#
# static unsigned long dirty_bytes_min,
# 	},
# 	{
# 		.procname	= "lease-break-time" },
# 	{},
# };
#
# static int _kdb_bp_install
#  *
#  * Return: 0 if a decrement the utime fields.
#  *
#  * But we don't clear LINKED
#  * flag of the process.
#  *
#  * Find empty slot in the results are advisory hints or for debugging is still a few 0-ref events on sleeping again. See the GNU General Public License for more details.
# 	 */
# 	do {
# 		chip = irq_desc_get_chip(desc)->flags & DELAYACCT_P

# %%
lm = train_char_lm("linux_input.txt", order=15)
print(generate_text(lm, 15))
# Out:
# ~
#  *     wait->flags &= ~WQ_FLAG_EXCLUSIVE) && !--nr_exclusive)
# 			break;
# 	}
#
# 	return parent;
# }
#
# /* Initialize all percpu queues used by parallel workers.
#  *
#  * @wq: workqueue to use
#  * @dwork: work to queue
#  *
#  * We queue the work to a specific cpu buffer.
#  *
#  * This is intended to get
#  * the system into a safe state for some of the manipulation, as well as saves the print format shown to users in the format file, it will not
#  * be migrated to this_cpu?
#  */
# static
# int can_migrate_task(struct rq *rq, struct task_struct *child)
# {
# 	BUG_ON(!child->ptrace || child->exit_state);
# 	int ret;
#
# 	if (
# #ifdef CONFIG_NO_HZ_FULL_SYSIDLE
# 	long long dynticks_idle_jiffies);
# 		P(next_jiffies);
# 		P_ns(idle_entrytime);
#
# 			idle = ktime_add(tk->offs_real, ktime_t *offs_boot,
# 							ktime_t *offs_tai);
#
# extern int kdb_state;
# #define RTWS_FIXED_DELAY	0
# #define RTWS_DELAY		1
# #define RTWS_REPLACE		2
# #define RTWS_DELAY		1
# #define RTWS_REPLACE		2
# #define RTWS_DEF_FREE		3
# #define RTWS_EXP_SYNC:
# 				rcu_torture_pi

# %%
lm = train_char_lm("linux_input.txt", order=20)
print(generate_text(lm, 20))
# Out:
# /*
#  * linux/kernel/irq/resend.c
#  *
#  * Copyright (C) 2011-2012 Red Hat, Inc., Frederic Weisbecker <fweisbec@gmail.com>
#  */
#
# /*
#  * HW_breakpoint: a unified kernel/user-space hardware breakpoint
#  * @bp: the breakpoint structure to unregister
#  */
# void unregister_wide_hw_breakpoint - unregister a wide breakpoint in the kernel
#  * @cpu_events: the per cpu set of events to unregister
#  */
# void unregister_hw_breakpoint(bp);
# 	if (err)
# 		return ERR_PTR(err);
# 	}
#
# 	ns->ns.ops = &utsns_operations;
#
# 	down_read(&uts_sem);
# 	if (copy_to_user(name, utsname(), sizeof *name))
# 		errno = -EFAULT;
# 	if (!copy_from_user(tmp, name, len)) {
# 		struct new_utsname *u = utsname();
#
# 		memcpy(u->domainname, tmp, len);
# 		memset(u->nodename + len, 0, sizeof(u->nodename) - len);
# 		errno = 0;
# 		uts_proc_notify(UTS_PROC_DOMAINNAME);
# 	}
# 	up_write(&uts_sem);
# 	return errno;
# }
#
# #ifdef __ARCH_WANT_SYS_ALARM
#
# /*
#  * For backwards compatibility?  If so,
#  * why not move it into the appropriate hierarchy.
#  */
# static bool cgrp_dfl_root

# %%
print(generate_text(lm, 20, nletters=5000))
# Out:
# /*
#  * linux/kernel/irq/autoprobe.c
#  *
#  * Copyright (C) Shailabh Nagar, IBM Corp. 2006
#  *           (C) Balbir Singh,   IBM Corp. 2006
#  *
#  * This program is free software; you can redistribute it and/or modify
#  *  it under the terms of the GNU General Public License for more details.
#  *
#  * Copyright (c) 2000-2004 Silicon Graphics, Inc.  All Rights Reserved.
#  */
#
# #include <linux/timer.h>
# #include <linux/tick.h>
# #include <trace/events/sched.h>
#
# #define CREATE_TRACE_POINTS
# #include <trace/events/sched.h>
#
# #define CPUPRI_NR_PRIORITIES; i++)
# 		free_cpumask_var(shuffle_tmp_mask);
# 	if (shuffle_idle_cpu >= nr_cpu_ids)
# 		return per_cpu_ptr(rsp->rda, cpu));
# 		rcu_organize_nocb_kthreads(struct rcu_state *rsp;
# 	int tne;
#
# 	/* Handle nohz enablement switches conservatively. */
# 	tne = ACCESS_ONCE(tick_nohz_active);
# 	if (tne != rdtp->tick_nohz_enabled_snap; /* Previously seen value from sysfs. */
# #endif /* #ifdef CONFIG_NO_HZ_COMMON
# /*
#  * Find out when the next timer event.
# 			 * If the time delta exceeds the maximum time delta
# 			 * permitted by the current clocksource.
#  */
# static ssize_t
# perf_read(struct file *filp, char __user *ubuf,
# 		       size_t cnt, loff_t *ppos)
# {
# 	return do_proc_dointvec(table, write, buffer, lenp, ppos);
# 	if (err < 0)
# 		return err;
#
# 	if (insn->src_reg == 0)
# 		/* generic move 64-bit immediate into a register */
# 		return 0;
#
# 	/* replace_map_fd_with_map_ptr() should have caught bad ld_imm64 */
# 	BUG_ON(insn->src_reg != BPF_REG_0 ||
# 				    insn->dst_reg != BPF_REG_0) {
# 			verbose("BPF_LDX uses reserved fields\n");
# 				return -EINVAL;
# 		}
# 		pred->val = val;
#
# 		fn = select_comparison_fn(int op, int field_size,
# 					     int field_is_signed)
# {
# 	filter_pred_fn_t fn = filter_pred_none;
# 	}
#
# 	return 0;
# }
#
# int set_tracer_flag(struct trace_array *tr, int graph)
# {
# 	int ret;
#
# 	ret = register_jprobes(jps, 2);
#
# 	return 0;
# }
# #ifdef CONFIG_KRETPROBES
# 	num_tests++;
# 	ret = test_jprobe();
# 	if (ret < 0)
# 		return ret;
#
# 	*ppos += cnt;
#
# 	return cnt;
# }
#
# static ssize_t
# trace_options_read(struct file *filp, char __user *ubuf,
# 		     size_t cnt, loff_t *ppos)
# {
# 	ssize_t ret;
# 	struct header_iter *hiter)
# {
# 	if (!hiter)
# 		return 0;
#
# 	mmio_print_pcidev(s, hiter->dev);
# 	hiter->dev = pci_get_device(PCI_ANY_ID, PCI_ANY_ID, NULL);
# 	iter->private = hiter;
# }
#
# /* XXX: This is not called when the pipe is closed! */
# static void mmio_close(struct trace_uprobe *tu;
#
# 	list_for_each_entry(tu, &uprobe_list, list)
# 		if (strcmp(ftrace_event_name(&tu->tp.call));
# 	seq_printf(m, "Mems_allowed_list:\t%*pbl\n",
# 		   nodemask_pr_args(&task->mems_allowed));
# 	seq_printf(m, "nfqs=%lu/nfqsng=%lu(%lu) fqlh=%lu oqlen=%ld/%ld\n",
# 		   rsp->n_force_qs, rsp->n_force_qs_ngp,
# 		   rsp->n_force_qs, rsp->n_force_qs_ngp,
# 		   rsp->n_force_qs, rsp->n_force_qs_ngp,
# 		   rsp->n_force_qs - rsp->n_force_qs_ngp,
# 		   rsp->n_force_qs, rsp->n_force_qs_ngp,
# 		   ACCESS_ONCE(rsp->completed) == gpnum) {
# 			pr_err("INFO: Stall ended before state dump start\n");
# 		} else {
# 			/*
# 			 * One of the primary handlers returned IRQ_HANDLED. If
# 		 * not we defer the spurious detection to the next
# 		 * interrupt.
# 		 */
# 		set_bit(IRQTF_AFFINITY, &action->thread_flags)) {
# 			__set_current_state(TASK_UNINTERRUPTIBLE,
# 				   0, &ctx->dep_map, _RET_IP_, ctx, 1);
# }
#
# #endif
#
# /*
#  * Spinlock based trylock, we take the spinlock and check whether we
#  * can get the lock:
#  */
# static inline void tick_irq_exit(void)
# {
# #ifdef CONFIG_SMP
# 		/*
# 		 * migrate_to_reboot_cpu();
#
# 		/*
# 		 * migrate_task_rq_fair(struct task_struct *p = curr_task(cpu);
# #ifdef	_TIF_MCA_INIT
# 	if ((task_thread_info(p)->cpu = cpu;
# 	p->wake_cpu = cpu;
# #endif
# }
#
# /*
#  * Tunables that become constants when CONFIG_SCHED_DEBUG */
#
# #endif /* CONFIG_SMP */
#
# /*
#  * This is the work-queue function that handles SRCU grace periods.
#  *
#  * The caller must hold rnp->lock with interrupts disabled.
#  *
#  * Return conditions are same as __raw_notifier_call_chain returns the value returned (which
#  * basically means that however wrong your real time clock is at boot time,
#  * you get the right time here).
#  */
# void getboottime64(struct timespec64 *ts64)
# {
# 	struct timespec now;
# 	unsigned long seq;
# 	s64 nsecs_raw, nsecs_real;
#
# 	WARN_ON_ONCE(timer_pending(timer));
# 	mod_timer(timer, timer->expires);
# }
# EXPORT_SYMBOL(_raw_write_unlock_irq(rwlock_t *lock)
# {
# 	int ret = arch_read_trylock(&lock->raw_lock);
# }
# /*
#  *
#  * Function graph tracer below.
#  *  This is OK, since the function graph tracer is
#  *  dependent on the function tracer always reports the address of where the
# 	 * mcount call was, but the stack will hold the return address.
# 	 */
# 	if (fentry)
# 		ip = parent_ip;
# 	else
# 		ip += MCOUNT_INSN_SIZE;
#
# 	check_stack(ip, &stack);
#
#  out:
# 	per_cpu(trace_active, cpu)++;
#
# 	arch_spin_lock(&max_stack_lock);
#
# 	per_cpu(trace_active, cpu)++;
#
# 	arch_spin_lock(&trace_clock_struct.lock);
#
# 	/*
# 	 * TODO: if this happens often then maybe we should reset
# 	 * my_scd->clock to prev_time+1, to make sure
# 	 * we start ticking with the local clock from now on?
# 	 */
# 	if ((s64)(now - trace_cloc
